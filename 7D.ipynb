# %%
# the back traversal on DLL for insertion in end:

class Node:
    def __init__(self,data):
        self.data=data
        self.prev=None
        self.next=None
class DoublyLinkedList:
    def __init__(self):
        self.head=None

    def iae(self,data):
        newnode=Node(data)
        if self.head is None:
            self.head=newnode
            return
        temp=self.head
        while temp.next:
            temp=temp.next
        temp.next=newnode
        newnode.prev=temp

    def backtraversal(self):
        print("values for traversing backward....")
        temp = self.head
        if not temp:
            print("list is empty")
            return
        while temp.next:
            temp = temp.next
        while temp:
            print(temp.data,end="<-->")
            temp = temp.prev
        print("None")
        
    def display(self):
        temp=self.head
        print("Doubly Linked List:")
        while temp:
            print(temp.data,end="<-->")
            temp=temp.next
        print("None")

dll=DoublyLinkedList()
n=int(input("Enter the nuber of elements to insert at end:"))
for i in range(n):
    val=int(input(f"enter elements {i+1}:"))
    dll.iae(val)
dll.display()
dll.backtraversal()
# Out:
# Doubly Linked List:
# 10<-->20<-->30<-->40<-->None
# values for traversing backward....
# 40<-->30<-->20<-->10<-->None

# %%
# the back traversal on DLL for insertion in beging:
class Node:
    def __init__(self, data):
        self.data = data
        self.prev = None
        self.next = None
class Double_linked_list:
    def __init__(self):
        self.head = None
    def iab(self,data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
            return
        new_node.next = self.head
        self.head.prev = new_node
        self.head = new_node
    def backtraverse(self):
        print("values for traversing backward....")
        temp = self.head
        if not temp:
            print("list is empty")
            return
        while temp.next:
            temp = temp.next
        while temp:
            print(temp.data,end="<-->")
            temp = temp.prev
        print("None")
    def display(self):
        temp=self.head
        print("Double Linked List:")
        while temp:
            print(temp.data,end="<-->")
            temp = temp.next
        print("None")
dll=Double_linked_list()
n= int(input("Enter the number of elements to insert at end: ")) #size
for i in range(n):
    val=int(input(f"Enter the element {i+1}: "))
    dll.iab(val)
dll.display()
dll.backtraverse()
# Out:
# Double Linked List:
# 4<-->3<-->2<-->1<-->None
# values for traversing backward....
# 1<-->2<-->3<-->4<-->None

# %%
#deleteting opertions in DLL:

#1.delete at begin /insert at begin
#2.delete at begin /insert at end
#3.delete at end   /insert at begin
#4.delete at end   /insert at end

# %%
#1.delete at begin /insert at begin

class Node:
    def __init__(self,data):
        self.data=data
        self.prev=None
        self.next=None
class DoublyLinkedList:
    def __init__(self):
        self.head=None
    def iab(self,data):
        newnode=Node(data)
        newnode.next=self.head
        if self.head:
            self.head.prev=self.head
        self.head=newnode
    
    def dab(self):
        if not self.head:
            print("can't perform delete in an empty list...")
        print(f"Deleted:{self.head.data}")
        self.head=self.head.next
        if self.head:
            self.head.prev=None
        
    def display(self):
        temp=self.head
        print("Doubly Linked List:")
        while temp:
            print(temp.data,end="<-->")
            temp=temp.next
        print("None")


dll=DoublyLinkedList()
n=int(input("Enter the nuber of elements to insert at end:"))
for i in range(n):
    val=int(input(f"enter elements {i+1}:"))
    dll.iab(val)
dll.display()
d=int(input("\n how many times u want to perform the delee op"))
for _ in range(d):
    dll.dab()
    dll.display()
# Out:
# Doubly Linked List:
# 4<-->3<-->2<-->1<-->None
# Deleted:4
# Doubly Linked List:
# 3<-->2<-->1<-->None
# Deleted:3
# Doubly Linked List:
# 2<-->1<-->None

# %%
#2.delete at begin /insert at end


class Node:
    def __init__(self, data):
        self.data = data
        self.prev = None
        self.next = None
class Double_linked_list:
    def __init__(self):
        self.head = None
    def iae(self,data):
        newnode=Node(data)
        if self.head is None:
            self.head=newnode
            return
        temp=self.head
        while temp.next:
            temp=temp.next
        temp.next=newnode
        newnode.prev=temp
    def dab(self):
        if not self.head:
            print("can't perform delete in an empty list...")
        print(f"Deleted:{self.head.data}")
        self.head=self.head.next
        if self.head:
            self.head.prev=None

    def dae(self):
        if self.head is None:
            print("can't perform delete in an empty list...")
            return
        temp=self.head
        while temp.next:
            temp=temp.next
        print(f"Deleted:{temp.data}")
        if temp.prev:
            temp.prev.next=None
        else:
            self.head=None


    def display(self):
        temp=self.head
        print("Double Linked List:")
        while temp:
            print(temp.data, end="<-->")
            temp = temp.next
        print("None")
dll=Double_linked_list()
n= int(input("Enter the number of elements to insert at end: ")) #size
for i in range(n):
    val=int(input(f"Enter the element {i+1}: "))
    dll.iae(val)
dll.display()
d=int(input("\n how many times you want to delete at end: ")) #delete at end / insert at begin
for i in range(d):
    dll.dab()
    dll.display()
# Out:
# Double Linked List:
# 1<-->2<-->3<-->4<-->None
# Deleted:1
# Double Linked List:
# 2<-->3<-->4<-->None
# Deleted:2
# Double Linked List:
# 3<-->4<-->None

# %%
#3.delete at end   /insert at begin

class Node:
    def __init__(self, data):
        self.data = data
        self.prev = None
        self.next = None
class Double_linked_list:
    def __init__(self):
        self.head = None
    def iab(self,data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
            return
        new_node.next = self.head
        self.head.prev = new_node
        self.head = new_node
    def dae(self):
        if self.head is None:
            print("List is empty cannot perform delete operation")
            return
        temp = self.head
        while temp.next:
            temp=temp.next
        print(f"Deleted: {temp.data}")
        if temp.prev:
            temp.prev.next = None
        else:
            self.head = None

    def dae(self):
        if self.head is None:
            print("can't perform delete in an empty list...")
            return
        temp=self.head
        while temp.next:
            temp=temp.next
        print(f"Deleted:{temp.data}")
        if temp.prev:
            temp.prev.next=None
        else:
            self.head=None


    def display(self):
        temp=self.head
        print("Double Linked List:")
        while temp:
            print(temp.data, end="<-->")
            temp = temp.next
        print("None")
dll=Double_linked_list()
n= int(input("Enter the number of elements to insert at end: ")) #size
for i in range(n):
    val=int(input(f"Enter the element {i+1}: "))
    dll.iab(val)
dll.display()
d=int(input("\n how many times you want to delete at end: ")) #delete at end / insert at begin
for i in range(d):
    dll.dae()
    dll.display()
# Out:
# Double Linked List:
# 4<-->3<-->2<-->1<-->None
# Deleted:1
# Double Linked List:
# 4<-->3<-->2<-->None
# Deleted:2
# Double Linked List:
# 4<-->3<-->None

# %%
#4.delete at end   /insert at end


class Node:
    def __init__(self, data):
        self.data = data
        self.prev = None
        self.next = None
class Double_linked_list:
    def __init__(self):
        self.head = None
    def iae(self,data):
        newnode=Node(data)
        if self.head is None:
            self.head=newnode
            return
        temp=self.head
        while temp.next:
            temp=temp.next
        temp.next=newnode
        newnode.prev=temp
    def dae(self):
        if self.head is None:
            print("List is empty cannot perform delete operation")
            return
        temp = self.head
        while temp.next:
            temp=temp.next
        print(f"Deleted: {temp.data}")
        if temp.prev:
            temp.prev.next = None
        else:
            self.head = None

    def dae(self):
        if self.head is None:
            print("can't perform delete in an empty list...")
            return
        temp=self.head
        while temp.next:
            temp=temp.next
        print(f"Deleted:{temp.data}")
        if temp.prev:
            temp.prev.next=None
        else:
            self.head=None


    def display(self):
        temp=self.head
        print("Double Linked List:")
        while temp:
            print(temp.data, end="<-->")
            temp = temp.next
        print("None")
dll=Double_linked_list()
n= int(input("Enter the number of elements to insert at end: ")) #size
for i in range(n):
    val=int(input(f"Enter the element {i+1}: "))
    dll.iae(val)
dll.display()
d=int(input("\n how many times you want to delete at end: ")) #delete at end / insert at begin
for i in range(d):
    dll.dae()
    dll.display()
# Out:
# Double Linked List:
# 1<-->2<-->3<-->4<-->None
# Deleted:4
# Double Linked List:
# 1<-->2<-->3<-->None
# Deleted:3
# Double Linked List:
# 1<-->2<-->None

# %%
# Deleting a element in a DLL by value:


class Node:
    def __init__(self, data):
        self.data = data
        self.prev = None
        self.next = None
class Double_linked_list:
    def __init__(self):
        self.head = None
    def iae(self,data):
        newnode=Node(data)
        if self.head is None:
            self.head=newnode
            return
        temp=self.head
        while temp.next:
            temp=temp.next
        temp.next=newnode
        newnode.prev=temp
    def dv(self,value):
        temp = self.head
        while temp:
            if temp.data==value:
                print(f"Deleted {temp.data}:")
                if temp.prev:
                    temp.prev.next=temp.next
                else:
                    self.head=temp.next
                if temp.next:
                    temp.next.prev=temp.prev
                return
            temp=temp.next
        print(f"{value} not found in the list")
    

    def dae(self):
        if self.head is None:
            print("can't perform delete in an empty list...")
            return
        temp=self.head
        while temp.next:
            temp=temp.next
        print(f"Deleted:{temp.data}")
        if temp.prev:
            temp.prev.next=None
        else:
            self.head=None


    def display(self):
        temp=self.head
        print("Double Linked List:")
        while temp:
            print(temp.data, end="<-->")
            temp = temp.next
        print("None")
dll=Double_linked_list()
n= int(input("Enter the number of elements to insert at end: ")) 
for i in range(n):
    val=int(input(f"Enter the element {i+1}: "))
    dll.iae(val)
dll.display()
d=int(input("\n how many times you want to delete at end: ")) 
for i in range(d):
    key=int(input("Enter the value u want to delete:"))
    dll.dv(key)
    dll.display()
# Out:
# Double Linked List:
# 1<-->2<-->3<-->4<-->5<-->6<-->None
# Deleted 3:
# Double Linked List:
# 1<-->2<-->4<-->5<-->6<-->None
# Deleted 1:
# Double Linked List:
# 2<-->4<-->5<-->6<-->None
# Deleted 5:
# Double Linked List:
# 2<-->4<-->6<-->None

# %%
# the back traversal on DLL for insertion in end:

class Node:
    def __init__(self,data):
        self.data=data
        self.prev=None
        self.next=None
class DoublyLinkedList:
    def __init__(self):
        self.head=None

    def iae(self,data):
        newnode=Node(data)
        if self.head is None:
            self.head=newnode
            return
        temp=self.head
        while temp.next:
            temp=temp.next
        temp.next=newnode
        newnode.prev=temp

    def dc(self):
        print("duplicate values in DLL:")
        return
    

        
    def display(self):
        temp=self.head
        print("Doubly Linked List:")
        while temp:
            print(temp.data,end="<-->")
            temp=temp.next
        print("None")

dll=DoublyLinkedList()
n=int(input("Enter the nuber of elements to insert at end:"))
for i in range(n):
    val=int(input(f"enter elements {i+1}:"))
    dll.iae(val)
dll.display()
dll.dc()
# Out:
# Doubly Linked List:
# 10<-->20<-->30<-->20<-->10<-->40<-->None
# duplicate values in DLL:
